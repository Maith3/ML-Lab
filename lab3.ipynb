# %%
import random

# %%
def objective_function(x):
  return -x**2+5

# %%
def hill_climbing(start_x, step_size, max_iter):
  current_x = start_x
  current_score=objective_function(current_x)
  
  for i in range(max_iter):
    new_x = current_x+random.uniform(-step_size,step_size)
    new_score=objective_function(new_x)
    print(f"current_x={current_x:.4f}, current_score={current_score:.4f}")
    if new_score>current_score:
      current_x=new_x
      current_score=new_score
    else:
      pass
  print("\nBest Solution")
  print(f"current_x={current_x:.4f}, current_score={current_score:.4f}")

# %%
hill_climbing(0.1,0.05,5)
# Out:
# current_x=0.1000, current_score=4.9900
# current_x=0.0521, current_score=4.9973
# current_x=0.0521, current_score=4.9973
# current_x=0.0469, current_score=4.9978
# current_x=0.0469, current_score=4.9978
#
# Best Solution
# current_x=0.0469, current_score=4.9978
